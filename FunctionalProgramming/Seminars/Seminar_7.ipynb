# %% [markdown]
# # Демонстрация примеров из лекции

# %%
(defun My_apply ( f L)
    ((lambda (fun x) (eval (cons fun x ))) f L))
# Out:
# MY_APPLY
# SB-KERNEL:REDEFINITION-WITH-DEFUN: redefining COMMON-LISP-USER::MY_APPLY in DEFUN

# %%
(my_apply '+ '(1 2 3 4))
# Out:
# 10

# %%
(my_apply '* '(1 2 3 4))
# Out:
# 24

# %%
(my_apply '- '(1 2 3 4))
# Out:
# -8

# %%
(my_apply '/ '(1 2 3 4))
# Out:
# 1/24

# %%
(my_apply 'car '(1 2 3 4))
# Out:
# SIMPLE-PROGRAM-ERROR: invalid number of arguments: 4
# 3: ((FLET "H1" :IN JUPYTER:EVALUATE-CODE) invalid number of arguments: 4)
# 4: (SB-KERNEL::%SIGNAL invalid number of arguments: 4)
# 5: (ERROR invalid number of arguments: 4)
# 6: (SB-INT:%PROGRAM-ERROR invalid number of arguments: ~S 4)
# 7: ("INVALID-ARG-COUNT-ERROR" 4)
# 8: (SB-KERNEL:INTERNAL-ERROR #.(SB-SYS:INT-SAP #X7FB4B527DA80) #<unused argument>)
# 9: ("foreign function: call_into_lisp")
# 10: ("foreign function: funcall2")
# 11: ("foreign function: interrupt_internal_error")
# 12: ("foreign function: handle_trap")
# 13: ("foreign function: #x418812")
# 14: (CAR 1 2 3 4)
# 15: (SB-INT:SIMPLE-EVAL-IN-LEXENV (CAR 1 2 3 4) #<NULL-LEXENV>)
# 16: (EVAL (CAR 1 2 3 4))
# 17: (JUPYTER/COMMON-LISP::EVAL-AND-PRINT (MY_APPLY (QUOTE CAR) (QUOTE (1 2 3 4))) 0 NIL)
# ...

# %%
(defun My_apply1 (f L) 
  ((lambda (fun x) 
    (eval (print (list fun (list 'quote x))))) f L))
# Out:
# MY_APPLY1
# SB-KERNEL:REDEFINITION-WITH-DEFUN: redefining COMMON-LISP-USER::MY_APPLY1 in DEFUN

# %%
(my_apply1 'car '(1 2 3 4))
# Out:
# 1
# (CAR '(1 2 3 4))

# %%
(my_apply1 'cdr '(1 2 3 4))
# Out:
# (2 3 4)
# (CDR '(1 2 3 4))

# %%
(my_apply1 '+ '(1 2 3 4))
# Out:
# TYPE-ERROR: The value
#   (1 2 3 4)
# is not of type
#   NUMBER
# 3: ((FLET "H1" :IN JUPYTER:EVALUATE-CODE) The value (1 2 3 4) is not of type NUMBER)
# 4: (SB-KERNEL::%SIGNAL The value (1 2 3 4) is not of type NUMBER)
# 5: (ERROR TYPE-ERROR DATUM (1 2 3 4) EXPECTED-TYPE NUMBER CONTEXT NIL)
# 6: (SB-KERNEL:INTERNAL-ERROR #.(SB-SYS:INT-SAP #X7FB4B527DA80) #<unused argument>)
# 7: ("foreign function: call_into_lisp")
# 8: ("foreign function: funcall2")
# 9: ("foreign function: interrupt_internal_error")
# 10: ("foreign function: handle_trap")
# 11: ("foreign function: #x418812")
# 12: (+ (1 2 3 4))
# 13: (SB-INT:SIMPLE-EVAL-IN-LEXENV (+ (QUOTE (1 2 3 4))) #<NULL-LEXENV>)
# 14: (EVAL (+ (QUOTE (1 2 3 4))))
# 15: (JUPYTER/COMMON-LISP::EVAL-AND-PRINT (MY_APPLY1 (QUOTE +) (QUOTE (1 2 3 4))) 0 NIL)
# ...

# %%
(apply '+ '(1 2 3 ))
# Out:
# 6

# %%
(apply 'car '(1 2 3 ))
# Out:
# SIMPLE-PROGRAM-ERROR: invalid number of arguments: 3
# 3: ((FLET "H1" :IN JUPYTER:EVALUATE-CODE) invalid number of arguments: 3)
# 4: (SB-KERNEL::%SIGNAL invalid number of arguments: 3)
# 5: (ERROR invalid number of arguments: 3)
# 6: (SB-INT:%PROGRAM-ERROR invalid number of arguments: ~S 3)
# 7: ("INVALID-ARG-COUNT-ERROR" 3)
# 8: (SB-KERNEL:INTERNAL-ERROR #.(SB-SYS:INT-SAP #X7FB4B527DB80) #<unused argument>)
# 9: ("foreign function: call_into_lisp")
# 10: ("foreign function: funcall2")
# 11: ("foreign function: interrupt_internal_error")
# 12: ("foreign function: handle_trap")
# 13: ("foreign function: #x418812")
# 14: (CAR 1 2 3)
# 15: (JUPYTER/COMMON-LISP::EVAL-AND-PRINT (APPLY (QUOTE CAR) (QUOTE (1 2 3))) 0 NIL)
# 16: ((:METHOD JUPYTER:EVALUATE-FORM (JUPYTER/COMMON-LISP:KERNEL T T T)) #<unused argument> #<FORM-TRACKING-STREAM for "file /tmp/F250C2655A9F44532C5123B57EED0A16-1557420670.lisp" {1006071B03}> CELL:1557420670.LISP.NEWEST NIL #<unused argument> #<unused argument>)
# ...

# %%
(apply '+ '(1 2 3 4))
# Out:
# 10

# %%
(funcall '+ 1 2 3 4)
# Out:
# 10

# %%
(defun My_funcall (f &rest L) 
  ((lambda (fun x) (eval (cons fun  x))) f L))
# Out:
# MY_FUNCALL

# %%
(my_funcall '+ 1 2 3 4)
# Out:
# 10

# %%
(defun test (&rest x)
    x)
# Out:
# TEST

# %%
(test '(1 2 3 4))
# Out:
# ((1 2 3 4))

# %%
(test 1 2 3 4)
# Out:
# (1 2 3 4)

# %%
(funcall 'cons 2 3)
# Out:
# (2 . 3)

# %%
(car '(2 . 3))
# Out:
# 2

# %%
(cdr '(2 . 3))
# Out:
# 3

# %%
(defun my_mapcar (f L) 
  (cond 
    ((Null L) nil) 
    (t (cons (funcall f (car L)) (my_mapcar f (cdr L))))))
# Out:
# MY_MAPCAR

# %%
(my_mapcar 'atom '(6 7 (7 5) nil h (5 3)))
# Out:
# (T T NIL T T NIL)

# %%
(defun sqr (x) (* x  x))
# Out:
# SQR

# %%
(my_mapcar 'sqr '(1 2 3 4 5))
# Out:
# (1 4 9 16 25)

# %%
(mapcar 'cons '(1 2 3) '(1 2 3))
# Out:
# ((1 . 1) (2 . 2) (3 . 3))

# %%
(my_mapcar 'cons '(1 2 3) '(1 2 3))
# Out:
# SIMPLE-PROGRAM-ERROR: invalid number of arguments: 3
# 3: ((FLET "H1" :IN JUPYTER:EVALUATE-CODE) invalid number of arguments: 3)
# 4: (SB-KERNEL::%SIGNAL invalid number of arguments: 3)
# 5: (ERROR invalid number of arguments: 3)
# 6: (SB-INT:%PROGRAM-ERROR invalid number of arguments: ~S 3)
# 7: ("INVALID-ARG-COUNT-ERROR" 3)
# 8: (SB-KERNEL:INTERNAL-ERROR #.(SB-SYS:INT-SAP #X7FB4B527DB80) #<unused argument>)
# 9: ("foreign function: call_into_lisp")
# 10: ("foreign function: funcall2")
# 11: ("foreign function: interrupt_internal_error")
# 12: ("foreign function: handle_trap")
# 13: ("foreign function: #x418812")
# 14: (MY_MAPCAR CONS (1 2 3) (1 2 3))
# 15: (JUPYTER/COMMON-LISP::EVAL-AND-PRINT (MY_MAPCAR (QUOTE CONS) (QUOTE (1 2 3)) (QUOTE (1 2 3))) 0 NIL)
# ...

# %%
(my_mapcar 'random '(20 30 40 70))
# Out:
# (13 17 7 45)

# %%
(my_mapcar (lambda (x) (* x x)) '(1 2 3 4 5))
# Out:
# (1 4 9 16 25)

# %%
(defun My_maplist (f L) 
  (cond 
    ((Null L) nil)
    (t (cons (funcall f L) (My_maplist f (cdr L))))))
# Out:
# MY_MAPLIST

# %%
(my_maplist 'reverse '(1 2 3 4))
# Out:
# ((4 3 2 1) (4 3 2) (4 3) (4))

# %%
(funcall (let ((y 10)) #'(lambda (x) (+ x y))) 1)
# Out:
# 11

# %%
(setq y 9)
# Out:
# 9
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::Y

# %%
y
# Out:
# 9
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::Y

# %%
(defun make_count (N)
  #'(lambda (x) 
    (if (>= N x) (setq N (- N x)) "No money")))
# Out:
# MAKE_COUNT
# SB-KERNEL:REDEFINITION-WITH-DEFUN: redefining COMMON-LISP-USER::MAKE_COUNT in DEFUN

# %%
(setq a (make_count 100))
# Out:
# #<CLOSURE (LAMBDA (X) :IN MAKE_COUNT) {100366AC7B}>
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::A

# %%
a
# Out:
# #<CLOSURE (LAMBDA (X) :IN MAKE_COUNT) {100366AC7B}>
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::A

# %%
(funcall a 5)
# Out:
# 95
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::A

# %%
(setq b (make_count 10))
# Out:
# #<CLOSURE (LAMBDA (X) :IN MAKE_COUNT) {10037A108B}>
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::B

# %%
(funcall b 5)
# Out:
# 5
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::B

# %%
(funcall a 90)
# Out:
# 5
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::A

# %%
(funcall b 6)
# Out:
# "No money"
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::B

# %%
(defun next (n) 
  #'(lambda () (prog1 (* n n) (setq n (+ n 1)))))
# Out:
# NEXT

# %%
(setq a (next 1))
# Out:
# #<CLOSURE (LAMBDA () :IN NEXT) {1003965F2B}>
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::A

# %%
(funcall a)
# Out:
# 64
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::A

# %%
(defun fib (n)
  (cond
    ((<= n 1) n)
    (t (+ (fib (- n 1)) (fib (- n 2))))))
# Out:
# FIB

# %%
(mapcar 'fib '(1 2 3 4 5 6 7 8 9))
# Out:
# (1 1 2 3 5 8 13 21 34)

# %%
(fib 40)
# Out:
# 102334155

# %%
(setf my-table (make-hash-table))
# Out:
# #<HASH-TABLE :TEST EQL :COUNT 0 {1003CE0593}>
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::MY-TABLE

# %%
(gethash 'key my-table)
# Out:
# NIL
# NIL
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::MY-TABLE

# %%
(setf (gethash 'key my-table) nil)
# Out:
# NIL
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::MY-TABLE

# %%
(gethash 'key my-table)
# Out:
# NIL
# T
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::MY-TABLE

# %%
(setf (gethash 'key my-table) 8)
# Out:
# 8
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::MY-TABLE

# %%
(+ (gethash 'key my-table) 9)
# Out:
# 17
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::MY-TABLE

# %%
(defun memoize  (my-function)
  (let ((my-table (make-hash-table)))
    #'(lambda (my-key)
      (multiple-value-bind (value foundp)
          (gethash my-key my-table)
	  (if foundp
	    value
	    (setf (gethash my-key my-table) 
              (funcall my-function my-key)))))))

(defun make-memoize (function-name)
  (setf (symbol-function function-name)
	(memoize (symbol-function function-name))))
# Out:
# MEMOIZE
# MAKE-MEMOIZE

# %%
(defun HV_To_Number (L) 	
  (cond 
     ((and (Null (cdr L)) (eq (car L) 'H)) 2) 
     ((and (Null (cdr L)) (eq (car L) 'V)) (/ 1 2)) 
     ((eq (car L) 'H) (+ 1 (HV_To_Number(cdr L)))) 
     ((eq (car L) 'V) (/ (HV_To_Number (cdr L))
                     (+ 1 (HV_To_Number(cdr L)))))))
# Out:
# HV_TO_NUMBER

# %%
(make-memoize 'hv_to_number)
# Out:
# #<CLOSURE (LAMBDA (MY-KEY) :IN MEMOIZE) {10041D3C5B}>

# %%
(hv_to_number '(v v v h h h h h v h v h v h h h v v v v h v  v v v h h h h h v h v h v h h h v v v v h v v v v h h h h h v h v h v h h h v v v v h v  v v v h h h h h v h v h v h h h v v v v h v v v v h h h h h v h v h v h h h v v v v h v  v v v h h h h h v h v h v h h h v v v v h v v v v h h h h h v h v h v h h h v v v v h v  v v v h h h h h v h v h v h h h v v v v h v v v v h h h h h v h v h v h h h v v v v h v  v v v h h h h h v h v h v h h h v v v v h v v v v h h h h h v h v h v h h h v v v v h v  v v v h h h h h v h v h v h h h v v v v h v v v v h h h h h v h v h v h h h v v v v h v  v v v h h h h h v h v h v h h h v v v v h v v v v h h h h h v h v h v h h h v v v v h v  v v v h h h h h v h v h v h h h v v v v h v ))
# Out:
# 7415418411646210456954165707321515699615926797451105685761/23565507895922370892000925283826060421239109341434227489281

# %%
(defun count-change (amount) 
  (cc amount 5)) 
(defun cc (amount kinds-of-coins) 
  (cond ((= amount 0) 1) 
         ((or (< amount 0) (= kinds-of-coins 0)) 0) 
         (t (+ (cc amount  (- kinds-of-coins 1)) 
                   (cc (- amount 
                   (first-denomination
                     kinds-of-coins)) 
                        kinds-of-coins))))) 
(defun first-denomination (kinds-of-coins) 
  (cond ((= kinds-of-coins 1) 1) 
         ((= kinds-of-coins 2) 5) 
         ((= kinds-of-coins 3) 10) 
         ((= kinds-of-coins 4) 25) 
         ((= kinds-of-coins 5) 50)))
# Out:
# COUNT-CHANGE
# CC
# FIRST-DENOMINATION
# SB-INT:SIMPLE-STYLE-WARNING: undefined function: COMMON-LISP-USER::CC
# SB-INT:SIMPLE-STYLE-WARNING: undefined function: COMMON-LISP-USER::FIRST-DENOMINATION

# %%
(count-change 900)
# Out:
# 536332

# %%
(make-memoize 'count-change)
# Out:
# #<CLOSURE (LAMBDA (MY-KEY) :IN MEMOIZE) {100440189B}>

# %% [markdown]
# # Символьное дифференцирование

# %%
(get 'p 'value)
# Out:
# NIL

# %%
(setf (get 'p 'value) 777)
# Out:
# 777

# %%
(get 'p 'value)
# Out:
# 777

# %%
(setf (get '+ 'proizvod) 'diff+)
(setf (get '* 'proizvod) 'diff*)
(setf (get '/ 'proizvod) 'diff/)
(setf (get '^ 'proizvod) 'diff^)
(setf (get '- 'proizvod) 'diff-)
(setf (get 'sin 'proizvod) 'diffsin)
(setf (get 'cos 'proizvod) 'diffcos)
(setf (get 'tan 'proizvod) 'difftan)
(setf (get 'log 'proizvod) 'difflog)
# Out:
# DIFF+
# DIFF*
# DIFF/
# DIFF^
# DIFF-
# DIFFSIN
# DIFFCOS
# DIFFTAN
# DIFFLOG

# %%
(get 'log 'proizvod)
# Out:
# DIFFLOG

# %%
;;Основная функция дифференцирования
(defun diff (L x)
	(cond 
		((atom L) (if (eq L x) 1 0))
		(t (funcall (get (first L) 'proizvod) (cdr L) x))))
# Out:
# DIFF

# %%
(defun diff+ (L x)
	(List '+ (diff (first L) x)
	(diff (second L) x)))
# Out:
# DIFF+

# %%
(defun diff- (L x)
	(List '- (diff (first L) x)
		 (diff (second L) x)))
# Out:
# DIFF-

# %%
(defun diff* (L x)
	(List '+ (List '* (diff (first L) x) (second L))
	(List '* (diff (second L) X) (first L))))

(defun diff/ (L x)
	(list '/
		(List '- (List '* (diff (first L) x) (second L))
		(List '* (diff (second L) X) (first L)))
		(list '* (second L) (second L))))
# Out:
# DIFF*
# DIFF/

# %%
(diff '(+ (* x x) (- 4 x)) 'x)
# Out:
# (+ (+ (* 1 X) (* 1 X)) (- 0 1))

# %%
(defun ^ (X N) (expt X N))
# Out:
# ^

# %%
(defun difflog (L x)
    (list '/ (diff (first L) x) (first L)))
# Out:
# DIFFLOG
# SB-KERNEL:REDEFINITION-WITH-DEFUN: redefining COMMON-LISP-USER::DIFFLOG in DEFUN

# %%
(diff '(+ x (log (* x x))) 'x)
# Out:
# (+ 1 (/ (+ (* 1 X) (* 1 X)) (* X X)))

# %%
(defun diffsin (L x)
    (list '* (list 'cos (first L)) (diff (first L) x)))
# Out:
# DIFFSIN
# SB-KERNEL:REDEFINITION-WITH-DEFUN: redefining COMMON-LISP-USER::DIFFSIN in DEFUN

# %%
(diff '(sin (* x x)) 'x)
# Out:
# (* (COS (* X X)) (+ (* 1 X) (* 1 X)))

# %%
(defun diffcos (L x)
    (list '* -1 (list '* (list 'sin (first L)) (diff (first L) x))))
# Out:
# DIFFCOS

# %%
(diff '(cos (* x x)) 'x)
# Out:
# (* -1 (* (SIN (* X X)) (+ (* 1 X) (* 1 X))))

# %%
(defun simple (L)
	(cond
		((atom L) L)
		((and (eq (first L) '+) (numberp (second L)) (numberp (third L))) 
                 (+ (second L) (third L)))
		((and (eq (first L) '+) (eq (second L) 0) ) (third L))
		((and (eq (first L) '+) (eq (third L) 0)) (second L))
		((and (eq (first L) '-) (numberp (second L)) (numberp (third L))) 
                (- (second L) (third L)))
		((and (eq (first L) '-) (eq (second L) 0) ) (list '* -1 (third L)))
		((and (eq (first L) '-) (eq (third L) 0)) (second L))
        ((equal L (simple L)) L)
        (t (simple L))))

# %%
(defmacro f(x) (+ x 1))
# Out:
# F

# %%
(f 4)
# Out:
# 5

# %%
(defun fnil (var) (setq var 0))
# Out:
# FNIL

# %%
(fnil 'x)
# Out:
# 0

# %%
x
# Out:
# UNBOUND-VARIABLE: The variable X is unbound.
# 3: ((FLET "H1" :IN JUPYTER:EVALUATE-CODE) The variable X is unbound.)
# 4: (SB-KERNEL::%SIGNAL The variable X is unbound.)
# 5: (ERROR The variable X is unbound.)
# 6: (SB-KERNEL:WITH-SIMPLE-CONDITION-RESTARTS ERROR NIL The variable X is unbound.)
# 7: ((LABELS SB-KERNEL::TRY :IN SB-KERNEL::RESTART-UNBOUND) The variable X is unbound.)
# 8: (SB-KERNEL::RESTART-UNBOUND X The variable X is unbound. -286)
# 9: (SB-KERNEL:INTERNAL-ERROR #.(SB-SYS:INT-SAP #X7FEA6260DB80) #<unused argument>)
# 10: ("foreign function: call_into_lisp")
# 11: ("foreign function: funcall2")
# 12: ("foreign function: interrupt_internal_error")
# 13: ("foreign function: handle_trap")
# 14: ("foreign function: #x418812")
# 15: ((LAMBDA NIL :IN "/tmp/FA0DE4DBA1ED47468D30598F0CAF6CA3-1431785024.lisp"))
# 16: (JUPYTER/COMMON-LISP::EVAL-AND-PRINT X 0 NIL)
# ...

# %%
(defun fnil_list (var) 
  (if (null var)
    nil
    (let () (set (car var) 0) (fnil_list (cdr var)))))
# Out:
# FNIL_LIST

# %%
(fnil_list '(a b c))
# Out:
# NIL

# %%
b
# Out:
# 0
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::B

# %%
c
# Out:
# 0
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::C

# %%
(defmacro mnil_list (&rest var)
  (list 'fnil_list (list 'quote var)))
# Out:
# MNIL_LIST
# SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining COMMON-LISP-USER::MNIL_LIST in DEFMACRO

# %%
(mnil_list z x v b p)
# Out:
# Control stack guard page temporarily disabled: proceed with caution
# ;
# ; compilation unit aborted
# ;   caught 1 fatal ERROR condition
# CONTROL-STACK-EXHAUSTED: Control stack exhausted (no more space for function call frames).
# This is probably due to heavily nested or infinitely recursive function
# calls, or a tail call that SBCL cannot or has not optimized away.
#
# PROCEED WITH CAUTION.
# 3: ((FLET "H1" :IN JUPYTER:EVALUATE-CODE) Control stack exhausted (no more space for function call frames).
# This is probably due to heavily nested or infinitely recursive function
# calls, or a tail call that SBCL cannot or has not optimized away.
#
# PROCEED WITH CAUTION.)
# 4: (SB-KERNEL::%SIGNAL Control stack exhausted (no more space for function call frames).
# This is probably due to heavily nested or infinitely recursive function
# calls, or a tail call that SBCL cannot or has not optimized away.
#
# PROCEED WITH CAUTION.)
# 5: (ERROR CONTROL-STACK-EXHAUSTED)
# ...

# %%
p
# Out:
# 0
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::P

# %%
b
# Out:
# 0
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::B

# %%
(defmacro mnil_list (&rest var) 
  (list 'cond 
    (list (list 'null (list 'quote var)) 'nil) 
  (list 't (list 'progn 
    (list 'set (list 'car  (list 'quote var)) 0) 
  (cons 'mnil_list (cdr var))))))
# Out:
# MNIL_LIST
# SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining COMMON-LISP-USER::MNIL_LIST in DEFMACRO

# %%
(defun fnil_list (var) 
  (if (null var)
    nil
    (let () (set (car var) 0) (fnil_list (cdr var)))))

# %%
(defmacro mnil (var)
    `(setq ,var 0))
# Out:
# MNIL

# %%
(mnil y)
# Out:
# 0
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::Y

# %%
y
# Out:
# 0
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::Y
