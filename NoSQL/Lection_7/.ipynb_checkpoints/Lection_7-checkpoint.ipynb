# %% [markdown]
# # Лекция 7. Построение кластера MongoDB

# %% [markdown]
# ## Основные компоненты кластера

# %% [markdown]
# До сих пор мы использовали MongoDB как одиночный сервер, то есть каждый экземпляр mongod управлял полной копией данных приложения.
#
# Даже в случае репликации каждая реплика содержит полную копию всех данных – такую же, как на любой другой реплике. Для большинства приложений хранение всего набора данных на одном
# сервере вполне приемлемо.
#
# Но по мере того как объем данных растет, приложение начинает предъявлять более высокие требования к пропускной способности по чтению и записи, и мощности стандартных серверов перестает хватать. В этой ситуации возникает потребность построения кластера.

# %% [markdown]
# Рассмотрим основные компоненты кластера.
#
# <img src="ris1.png">

# %% [markdown]
# Сегментированный кластер состоит из сегментов, маршрутизаторов mongos и конфигурационных серверов.
#
# **Сегменты**
#
# Сегментированный кластер MongoDB распределяет данные по одному или нескольким сегментам. Каждый сегмент развертывается в виде набора реплик, на котором хранится некоторая часть всего множества данных. Поскольку сегмент представляет собой набор реплик, то он поддерживает автоматическую отработку отказов. К отдельному сегменту можно подключаться так же, как к автономному набору реплик. Но если мы подключитесь к одному набору реплик, то
# будете видеть только часть всех данных кластера.
#
# **Маршрутизаторы**
#
# Поскольку каждый сегмент содержит лишь часть данных кластера, то необходим интерфейс для обращения к кластеру как к единому целому. Эту роль выполняют процессы mongos. Каждый такой
# процесс – это маршрутизатор, перенаправляющий все операции чтения и записи подходящему сегменту. За счет этого mongos предоставляет клиентам единый взгляд на систему в целом.
#
# Процессы mongos потребляют мало ресурсов и не отвечают за сохранение данных. Приложение локально соединяется с mongos , а mongos уже управляет соединениями с конкретными сегментами.
#
# **Конфигурационные серверы**
#
# Если процессы mongos не сохраняют данные, то должен быть какой-то компонент, отвечающий за долговременное хранение  состояния сегментированного кластера; этим занимаются
# конфигурационные серверы, которые хранят метаданные кластера.
#
# В состав этих данных входят: глобальная конфигурация кластера, местоположение каждой базы данных, коллекции и диапазоны хранящихся в них данных, а также журнал изменений, в котором сохраняется история миграции данных между сегментами.
#
# Метаданные, хранящиеся на конфигурационных серверах, играют важнейшую роль для правильного функционирования и обслуживания кластера. Например, при каждом запуске процесс mongos
# получает копию метаданных от конфигурационных серверов. Без этих данных невозможно обеспечить согласованное представление сегментированного кластера. Таким образом, важность этих данных диктует стратегию проектирования и развертывания конфигурационных серверов.
#
# В любой производственной системе, где применяется сегментирование, должно быть ровно три конфигурационных сервера, причем для обеспечения резервирования они должны размещаться на разных машинах. Для отправки им данных из процесса mongos применяется протокол двухфазной фиксации, который гарантирует согласованность всех конфигурационных серверов.

# %% [markdown]
# ## Операции сегментирования

# %% [markdown]
# Кластер MongoDB распределяет данные между сегментами на двух уровнях:
# - на уровне базы данных;
# - на уровне коллекции.

# %% [markdown]
# Распределение на уровне базы данных заключается в том, что одна база данных будет вся содержаться в одном сегменте (каждой создаваемой в кластере базе данных назначается свой сегмент).
#
# Сегментирование на уровне коллекции позволяет содержать разные коллекции в разных сегментах.
#
# В MongoDB сегментирование производится по диапазону. Это означает, что для каждого документа в сегментированной коллекции определяется, в какой диапазон попадает значение заданного ключа.
# Чтобы отнести документ к конкретному диапазону, в MongoDB используется так называемый **сегментный ключ (shard key)**. Для создания сегментного ключа можно использовать "_id", однако лучше брать комбинацию полей.
#
# Еще одним важным понятием является  понятие **порции** (chunk). Порция – это непрерывный диапазон значений сегментных ключей, находящихся в одном сегменте.
#
# Важная характеристика порций – это то, что они не физические, а логические. Другими словами, порции не соответствуют последовательность соседних документов на диске.
#
# В основе механизма сегментирования лежит **расщепление и миграция порций**.
#
# Сначала рассмотрим идею расщепления порций. Сразу после настройки сегментированного кластера существует всего одна порция.
# Ее диапазон охватывает всю сегментированную коллекцию.
#
# Порция расщепляется по достижению определенного порогового размера. По умолчанию максимальный размер порции составляет 64 МБ или 100 000 документов, в зависимости от того, что будет достигнуто раньше. По мере добавления данных в новый сегментированный кластер первоначальная порция в конце концов достигает того или другого порога, после чего происходит ее расщепление. Расщепление – простая операция; по существу, она сводится к разбиению исходного диапазона на два поддиапазона и созданию двух новых порций с одинаковым количеством документов в каждой. Расщепление порции – это логическая операция.
# MongoDB просто изменяет метаданные, так что из одной порции получается две. Поэтому расщепление не оказывает влияния на физическое расположение документов в сегментированной коллекции, а,
# значит, происходит быстро.
#
# Одна из самых трудных проблем при проектировании сегментированной системы – обеспечить равномерное балансирование данных. Кластеры MongoDB достигают этого за счет перемещения порций между сегментами. Эта операция называется
# миграцией и, в отличие, от расщепления она подразумевает физические действия.
#
# Миграциями управляет процесс, который называется балансировщиком. Его задача заключается в том, чтобы обеспечить равномерное
# распределение данных между сегментами. Чтобы ее решить, балансировщик учитывает количество порций в каждом сегменте.
#
# Эвристические правила в какой-то мере зависят от полного размера данных, но обычно балансирование производится, когда разность между сегментом с наибольшим количеством порций и сегментом с наименьшим количеством порций оказывается больше восьми. В процессе балансирования порции перемещаются с сегмента, где их больше, на сегмент, где их меньше, пока количество порций не станет примерно одинаковым.

# %% [markdown]
# ## Создание сегментированного кластера

# %% [markdown]
# Сегментированный кластер настраивается в два этапа. На первом запускаются все необходимые процессы mongod и mongos. На втором, более простом, выполняются команды инициализации кластера. Наш кластер будет состоять из двух сегментов и трех конфигурационных серверов. При этом мы запустим всего один процесс mongos для взаимодействия с кластером. На рисунке представлены все рабочие процессы, и для каждого в скобках указан номер порта.
#
# <img src="ris2.png">

# %% [markdown]
# **Инициализация компонентов кластера**
#
# > mkdir /data/a1
#
# > mkdir /data/a2
#
# > mkdir /data/a3
#
# > mkdir /data/b1
#
# > mkdir /data/b2
#
# > mkdir /data/b3
#
# Теперь запустим процессы mongod:
#
# > mongod --shardsvr --replSet shard-a --dbpath ~/data/a1 --port 30000 --logpath ~/data/a1.log --nojournal
#
# > mongod --shardsvr --replSet shard-a --dbpath ~/data/a2 --port 30001 --logpath ~/data/a2.log --nojournal
#
# > mongod --shardsvr --replSet shard-a --dbpath ~/data/a3 --port 30002 --logpath ~/data/a3.log --nojournal
#
#
#
# Также запускаем второй набор реплик:
#
# > mongod --shardsvr --replSet shard-b --dbpath ~/data/b1 --port 30100 --logpath ~/data/b1.log --nojournal
#
# > mongod --shardsvr --replSet shard-b --dbpath ~/data/b2 --port 30101 --logpath ~/data/b2.log --nojournal
#
# > mongod --shardsvr --replSet shard-b --dbpath ~/data/b3 --port 30102 --logpath ~/data/b3.log --nojournal
#
# Наборы реплик необходимо инициализировать, для этого необходимо подключиться к каждому по очереди и выполнить команды:
#
# $ mongo localhost:30000
#
# > rs.initiate()
#
# После того, как данный сервер станет первичным, следует добавить остальные узлы:
#
# > rs.add("localhost:30001")
#
# > rs.addArb("localhost:30002")
#
# Второй набор реплик инициализируется аналогично.
#
# $ mongo localhost:30100
#
# > rs.initiate()
#
# > rs.add("localhost:30101")
#
# > rs.addArb("localhost:30102")
#
# Оба набора реплик можно проверить командой rs.status().
#
# Если на данном этапе все заработало, можно переходить к запуску конфигурационных серверов. Создадим для каждого сервера отдельный каталог, и запустим по одному процессу mongod с параметром configsvr:
#
#
# $ mkdir ~/data/config-1
#
# $ mongod --configsvr --replSet configrs --dbpath ~/data/config-1 --port 27019 --bind_ip localhost
#
# $ mkdir ~/data/config-2
#
# $  mongod --configsvr --replSet configrs --dbpath ~/data/config-2 --port 27020 --bind_ip localhost
#
# $ mkdir ~/data/config-3
#
# $  mongod --configsvr --replSet configrs --dbpath ~/data/config-3 --port 27021 --bind_ip localhost
#
# Зададим настройку реплики
#
# $ mongo --port 27019
#
# > rs.initiate( { _id: "configrs", members: [ { _id : 0, host : "localhost:27019" }, { _id : 1, host : "localhost:27020" }, { _id : 2, host : "localhost:27021" } ] } )
#
# Теперь можно запускать mongos маршрутизатор. При его запуске следует указать параметр configdb,
# значением которого является список адресов конфигурационных баз данных через запятую (или главный сервер реплики):
#
# $ mongos --configdb configrs/localhost:27019 --bind_ip localhost --port 40000

# %% [markdown]
# **Настройка конфигурации**
#
# Теперь все компоненты сегментированного кластера на месте и можно заняться его конфигурированием. Начнем с процесса mongos.
# Чтобы упростить задачу, воспользуемся вспомогательными методами сегментирования. Все они вызываются от имени глобального объекта sh. Чтобы вывести список имеющихся методов, выполните команду sh.help().
#
# Первым делом подключаемся к маршрутизатору и прописываем шарды:
#
# $ mongo --port 40000
#
# > sh.addShard("shard-a/localhost:30000")
#
# > sh.addShard("shard-a/localhost:30001")
#
# > sh.addShard("shard-b/localhost:30100")
#
# > sh.addShard("shard-b/localhost:30101")
#
# Чтобы посмотреть настройку шардирования, можно использовать следующие команды:
#
# > db.getSiblingDB("config").shards.find()
#
# или более кратко:
#
# > use admin
#
# > db.runCommand({listshards: 1})
#
# Более подробную информацию можно получить командой:
#
# > sh.status()
#
# Важным шагом является разрешенние на сегментацию базы данных. Это обязательное условие для сегментирования любой коллекции.
# Назовем нашу базу данных rebus, тогда команда разрешения сегментации выглядит так:
#
# > sh.enableSharding("rebus")
#
# В конфигурационной базе данных имеется коллекция databases , содержащая список баз данных. В каждом документе из этого списка указано местоположение основного сегмента базы и признак partitioned , говорящий о том, сегментирована она или нет.
#
# > use config
#
# > db.databases.find()
#
# { "_id" : "rebus", "primary" : "shard-b", "partitioned" : true }
#
# Теперь можно сегментировать какую-либо коллекцию. При этом определяется сегментный ключ, например, можно использовать составной или простой ключ. Если мы хотим, чтобы ключ  был хэширован, можно вместо этого использовать параметр {"myshardkey":"hashed"}:
#
# > sh.shardCollection("rebus.mycollect", {"_id":"hashed"})
#
# Чтобы посмотреть информацию о шардировании, можно использовать команду:
#
# > db.printShardingStatus()
#
#
# После того как коллекция сегментирована, кластер наконец-то готов к работе. Если теперь мы начнем писать в кластер, то данные будут распределяться по сегментам.

# %% [markdown]
# ## Запись в сегментированный кластер

# %% [markdown]
# Будем писать в сегментированную коллекцию и наблюдать за формированием и перемещением порций, что и составляет суть сегментирования в MongoDB.
#
# Подключаемся к маршрутизатору из Python:

# %%
import pymongo as pm

# Подключение к серверу
client = pm.MongoClient('localhost', 40000)

# Подключение к базе данных
db = client['rebus']

# Получение доступа к коллекции
collection = db['mycollect']

# %%
collection.find()

# %%
[i for i in collection.find()]
# Out:
# [{'_id': ObjectId('629986bdac000e3c60234b86'), 'name': 'Piter'}]

# %% [markdown]
# Запишем в коллекцию 200 документов:

# %%
for i in range(600):
    collection.insert_one({'name':"Serge",'age':i})

# %%
dir(collection)
# Out:
# ['_BaseObject__codec_options',
#  '_BaseObject__read_concern',
#  '_BaseObject__read_preference',
#  '_BaseObject__write_concern',
#  '_Collection__create',
#  '_Collection__create_indexes',
#  '_Collection__database',
#  '_Collection__find_and_modify',
#  '_Collection__full_name',
#  '_Collection__name',
#  '_Collection__write_response_codec_options',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_aggregate',
#  '_aggregate_one_result',
#  '_command',
#  '_count_cmd',
#  '_delete',
#  '_delete_retryable',
#  '_insert_one',
#  '_is_protocol',
#  '_read_preference_for',
#  '_retryable_non_cursor_read',
#  '_socket_for_reads',
#  '_socket_for_writes',
#  '_update',
#  '_update_retryable',
#  '_write_concern_for',
#  '_write_concern_for_cmd',
#  'aggregate',
#  'aggregate_raw_batches',
#  'bulk_write',
#  'codec_options',
#  'count_documents',
#  'create_index',
#  'create_indexes',
#  'database',
#  'delete_many',
#  'delete_one',
#  'distinct',
#  'drop',
#  'drop_index',
#  'drop_indexes',
#  'estimated_document_count',
#  'find',
#  'find_one',
#  'find_one_and_delete',
#  'find_one_and_replace',
#  'find_one_and_update',
#  'find_raw_batches',
#  'full_name',
#  'index_information',
#  'insert_many',
#  'insert_one',
#  'list_indexes',
#  'name',
#  'next',
#  'options',
#  'read_concern',
#  'read_preference',
#  'rename',
#  'replace_one',
#  'update_many',
#  'update_one',
#  'watch',
#  'with_options',
#  'write_concern']

# %% [markdown]
# Убедимся, что запись в кластер произошла:

# %%
[i for i in collection.find()]
# Out:
# [{'_id': ObjectId('629986bdac000e3c60234b86'), 'name': 'Piter'},
#  {'_id': ObjectId('629986d8531fa74537c69187'), 'name': 'Dascha', 'age': 0},
#  {'_id': ObjectId('629986d8531fa74537c6918a'), 'name': 'Dascha', 'age': 3},
#  {'_id': ObjectId('629986d8531fa74537c69190'), 'name': 'Dascha', 'age': 9},
#  {'_id': ObjectId('629986d8531fa74537c69194'), 'name': 'Dascha', 'age': 13},
#  {'_id': ObjectId('629986d8531fa74537c69196'), 'name': 'Dascha', 'age': 15},
#  {'_id': ObjectId('629986d8531fa74537c69197'), 'name': 'Dascha', 'age': 16},
#  {'_id': ObjectId('629986d8531fa74537c69198'), 'name': 'Dascha', 'age': 17},
#  {'_id': ObjectId('629986d8531fa74537c69199'), 'name': 'Dascha', 'age': 18},
#  {'_id': ObjectId('629986d8531fa74537c6919a'), 'name': 'Dascha', 'age': 19},
#  {'_id': ObjectId('629986d8531fa74537c6919b'), 'name': 'Dascha', 'age': 20},
#  {'_id': ObjectId('629986d8531fa74537c6919c'), 'name': 'Dascha', 'age': 21},
#  {'_id': ObjectId('629986d8531fa74537c6919d'), 'name': 'Dascha', 'age': 22},
#  {'_id': ObjectId('629986d8531fa74537c6919e'), 'name': 'Dascha', 'age': 23},
#  {'_id': ObjectId('629986d8531fa74537c6919f'), 'name': 'Dascha', 'age': 24},
#  {'_id': ObjectId('629986d8531fa74537c691a2'), 'name': 'Dascha', 'age': 27},
#  {'_id': ObjectId('629986d8531fa74537c691a3'), 'name': 'Dascha', 'age': 28},
#  {'_id': ObjectId('629986d8531fa74537c691a4'), 'name': 'Dascha', 'age': 29},
#  {'_id': ObjectId('629986d8531fa74537c691a5'), 'name': 'Dascha', 'age': 30},
#  {'_id': ObjectId('629986d8531fa74537c691a8'), 'name': 'Dascha', 'age': 33},
#  {'_id': ObjectId('629986d8531fa74537c691aa'), 'name': 'Dascha', 'age': 35},
#  {'_id': ObjectId('629986d8531fa74537c691ab'), 'name': 'Dascha', 'age': 36},
#  {'_id': ObjectId('629986d8531fa74537c691ac'), 'name': 'Dascha', 'age': 37},
#  {'_id': ObjectId('629986d8531fa74537c691ad'), 'name': 'Dascha', 'age': 38},
#  {'_id': ObjectId('629986d8531fa74537c691ae'), 'name': 'Dascha', 'age': 39},
#  {'_id': ObjectId('629986d8531fa74537c691b0'), 'name': 'Dascha', 'age': 41},
#  {'_id': ObjectId('629986d8531fa74537c691b2'), 'name': 'Dascha', 'age': 43},
#  {'_id': ObjectId('629986d8531fa74537c691b4'), 'name': 'Dascha', 'age': 45},
#  {'_id': ObjectId('629986d8531fa74537c691b5'), 'name': 'Dascha', 'age': 46},
#  {'_id': ObjectId('629986d8531fa74537c691ba'), 'name': 'Dascha', 'age': 51},
#  {'_id': ObjectId('629986d8531fa74537c691bb'), 'name': 'Dascha', 'age': 52},
#  {'_id': ObjectId('629986d8531fa74537c691bc'), 'name': 'Dascha', 'age': 53},
#  {'_id': ObjectId('629986d8531fa74537c691be'), 'name': 'Dascha', 'age': 55},
#  {'_id': ObjectId('629986d8531fa74537c691bf'), 'name': 'Dascha', 'age': 56},
#  {'_id': ObjectId('629986d8531fa74537c691c2'), 'name': 'Dascha', 'age': 59},
#  {'_id': ObjectId('629986d8531fa74537c691c3'), 'name': 'Dascha', 'age': 60},
#  {'_id': ObjectId('629986d8531fa74537c691c6'), 'name': 'Dascha', 'age': 63},
#  {'_id': ObjectId('629986d8531fa74537c691c7'), 'name': 'Dascha', 'age': 64},
#  {'_id': ObjectId('629986d8531fa74537c691c8'), 'name': 'Dascha', 'age': 65},
#  {'_id': ObjectId('629986d8531fa74537c691c9'), 'name': 'Dascha', 'age': 66},
#  {'_id': ObjectId('629986d8531fa74537c691cc'), 'name': 'Dascha', 'age': 69},
#  {'_id': ObjectId('629986d8531fa74537c691cd'), 'name': 'Dascha', 'age': 70},
#  {'_id': ObjectId('629986d8531fa74537c691cf'), 'name': 'Dascha', 'age': 72},
#  {'_id': ObjectId('629986d8531fa74537c691d1'), 'name': 'Dascha', 'age': 74},
#  {'_id': ObjectId('629986d8531fa74537c691d2'), 'name': 'Dascha', 'age': 75},
#  {'_id': ObjectId('629986d8531fa74537c691d3'), 'name': 'Dascha', 'age': 76},
#  {'_id': ObjectId('629986d8531fa74537c691d5'), 'name': 'Dascha', 'age': 78},
#  {'_id': ObjectId('629986d8531fa74537c691d7'), 'name': 'Dascha', 'age': 80},
#  {'_id': ObjectId('629986d8531fa74537c691d8'), 'name': 'Dascha', 'age': 81},
#  {'_id': ObjectId('629986d8531fa74537c691d9'), 'name': 'Dascha', 'age': 82},
#  {'_id': ObjectId('629986d8531fa74537c691da'), 'name': 'Dascha', 'age': 83},
#  {'_id': ObjectId('629986d8531fa74537c691db'), 'name': 'Dascha', 'age': 84},
#  {'_id': ObjectId('629986d8531fa74537c691de'), 'name': 'Dascha', 'age': 87},
#  {'_id': ObjectId('629986d8531fa74537c691e0'), 'name': 'Dascha', 'age': 89},
#  {'_id': ObjectId('629986d8531fa74537c691e1'), 'name': 'Dascha', 'age': 90},
#  {'_id': ObjectId('629986d8531fa74537c691e3'), 'name': 'Dascha', 'age': 92},
#  {'_id': ObjectId('629986d8531fa74537c691e4'), 'name': 'Dascha', 'age': 93},
#  {'_id': ObjectId('629986d8531fa74537c691e5'), 'name': 'Dascha', 'age': 94},
#  {'_id': ObjectId('629986d8531fa74537c691e8'), 'name': 'Dascha', 'age': 97},
#  {'_id': ObjectId('629986d8531fa74537c691ea'), 'name': 'Dascha', 'age': 99},
#  {'_id': ObjectId('629986d8531fa74537c691eb'), 'name': 'Dascha', 'age': 100},
#  {'_id': ObjectId('629986d8531fa74537c691ed'), 'name': 'Dascha', 'age': 102},
#  {'_id': ObjectId('629986d8531fa74537c691f0'), 'name': 'Dascha', 'age': 105},
#  {'_id': ObjectId('629986d8531fa74537c691f1'), 'name': 'Dascha', 'age': 106},
#  {'_id': ObjectId('629986d8531fa74537c691f5'), 'name': 'Dascha', 'age': 110},
#  {'_id': ObjectId('629986d8531fa74537c691f6'), 'name': 'Dascha', 'age': 111},
#  {'_id': ObjectId('629986d8531fa74537c691f7'), 'name': 'Dascha', 'age': 112},
#  {'_id': ObjectId('629986d8531fa74537c691fa'), 'name': 'Dascha', 'age': 115},
#  {'_id': ObjectId('629986d8531fa74537c691fb'), 'name': 'Dascha', 'age': 116},
#  {'_id': ObjectId('629986d8531fa74537c691fc'), 'name': 'Dascha', 'age': 117},
#  {'_id': ObjectId('629986d8531fa74537c691fd'), 'name': 'Dascha', 'age': 118},
#  {'_id': ObjectId('629986d8531fa74537c691ff'), 'name': 'Dascha', 'age': 120},
#  {'_id': ObjectId('629986d8531fa74537c69200'), 'name': 'Dascha', 'age': 121},
#  {'_id': ObjectId('629986d8531fa74537c6918e'), 'name': 'Dascha', 'age': 7},
#  {'_id': ObjectId('629986d8531fa74537c6918f'), 'name': 'Dascha', 'age': 8},
#  {'_id': ObjectId('629986d8531fa74537c69191'), 'name': 'Dascha', 'age': 10},
#  {'_id': ObjectId('629986d8531fa74537c69192'), 'name': 'Dascha', 'age': 11},
#  {'_id': ObjectId('629986d8531fa74537c69193'), 'name': 'Dascha', 'age': 12},
#  {'_id': ObjectId('629986d8531fa74537c69195'), 'name': 'Dascha', 'age': 14},
#  {'_id': ObjectId('629986d8531fa74537c691a0'), 'name': 'Dascha', 'age': 25},
#  {'_id': ObjectId('629986d8531fa74537c691a1'), 'name': 'Dascha', 'age': 26},
#  {'_id': ObjectId('629986d8531fa74537c691a6'), 'name': 'Dascha', 'age': 31},
#  {'_id': ObjectId('629986d8531fa74537c691a7'), 'name': 'Dascha', 'age': 32},
#  {'_id': ObjectId('629986d8531fa74537c691a9'), 'name': 'Dascha', 'age': 34},
#  {'_id': ObjectId('629986d8531fa74537c691af'), 'name': 'Dascha', 'age': 40},
#  {'_id': ObjectId('629986d8531fa74537c691b1'), 'name': 'Dascha', 'age': 42},
#  {'_id': ObjectId('629986d8531fa74537c691b3'), 'name': 'Dascha', 'age': 44},
#  {'_id': ObjectId('629986d8531fa74537c691b6'), 'name': 'Dascha', 'age': 47},
#  {'_id': ObjectId('629986d8531fa74537c691b7'), 'name': 'Dascha', 'age': 48},
#  {'_id': ObjectId('629986d8531fa74537c691b8'), 'name': 'Dascha', 'age': 49},
#  {'_id': ObjectId('629986d8531fa74537c691b9'), 'name': 'Dascha', 'age': 50},
#  {'_id': ObjectId('629986d8531fa74537c691bd'), 'name': 'Dascha', 'age': 54},
#  {'_id': ObjectId('629986d8531fa74537c691c0'), 'name': 'Dascha', 'age': 57},
#  {'_id': ObjectId('629986d8531fa74537c691c1'), 'name': 'Dascha', 'age': 58},
#  {'_id': ObjectId('629986d8531fa74537c691c4'), 'name': 'Dascha', 'age': 61},
#  {'_id': ObjectId('629986d8531fa74537c691c5'), 'name': 'Dascha', 'age': 62},
#  {'_id': ObjectId('629986d8531fa74537c691ca'), 'name': 'Dascha', 'age': 67},
#  {'_id': ObjectId('629986d8531fa74537c691cb'), 'name': 'Dascha', 'age': 68},
#  {'_id': ObjectId('629986d8531fa74537c691ce'), 'name': 'Dascha', 'age': 71},
#  {'_id': ObjectId('629986d8531fa74537c691d0'), 'name': 'Dascha', 'age': 73},
#  {'_id': ObjectId('629986d8531fa74537c691d4'), 'name': 'Dascha', 'age': 77},
#  {'_id': ObjectId('629986d8531fa74537c691d6'), 'name': 'Dascha', 'age': 79},
#  {'_id': ObjectId('629986d8531fa74537c691dc'), 'name': 'Dascha', 'age': 85},
#  {'_id': ObjectId('629986d8531fa74537c691dd'), 'name': 'Dascha', 'age': 86},
#  {'_id': ObjectId('629986d8531fa74537c691df'), 'name': 'Dascha', 'age': 88},
#  {'_id': ObjectId('629986d8531fa74537c691e2'), 'name': 'Dascha', 'age': 91},
#  {'_id': ObjectId('629986d8531fa74537c691e6'), 'name': 'Dascha', 'age': 95},
#  {'_id': ObjectId('629986d8531fa74537c692ba'), 'name': 'Dascha', 'age': 307},
#  {'_id': ObjectId('629986d8531fa74537c692bb'), 'name': 'Dascha', 'age': 308},
#  {'_id': ObjectId('629986d9531fa74537c692c1'), 'name': 'Dascha', 'age': 314},
#  {'_id': ObjectId('629986d9531fa74537c692c2'), 'name': 'Dascha', 'age': 315},
#  {'_id': ObjectId('629986d9531fa74537c692c3'), 'name': 'Dascha', 'age': 316},
#  {'_id': ObjectId('629986d9531fa74537c692c4'), 'name': 'Dascha', 'age': 317},
#  {'_id': ObjectId('629986d9531fa74537c692c8'), 'name': 'Dascha', 'age': 321},
#  {'_id': ObjectId('629986d9531fa74537c692cb'), 'name': 'Dascha', 'age': 324},
#  {'_id': ObjectId('629986d9531fa74537c692ce'), 'name': 'Dascha', 'age': 327},
#  {'_id': ObjectId('629986d9531fa74537c692cf'), 'name': 'Dascha', 'age': 328},
#  {'_id': ObjectId('629986d9531fa74537c692d3'), 'name': 'Dascha', 'age': 332},
#  {'_id': ObjectId('629986d9531fa74537c692d5'), 'name': 'Dascha', 'age': 334},
#  {'_id': ObjectId('629986d9531fa74537c692d7'), 'name': 'Dascha', 'age': 336},
#  {'_id': ObjectId('629986d9531fa74537c692da'), 'name': 'Dascha', 'age': 339},
#  {'_id': ObjectId('629986d9531fa74537c692dd'), 'name': 'Dascha', 'age': 342},
#  {'_id': ObjectId('629986d9531fa74537c692de'), 'name': 'Dascha', 'age': 343},
#  {'_id': ObjectId('629986d9531fa74537c692e0'), 'name': 'Dascha', 'age': 345},
#  {'_id': ObjectId('629986d9531fa74537c692e5'), 'name': 'Dascha', 'age': 350},
#  {'_id': ObjectId('629986d9531fa74537c692e6'), 'name': 'Dascha', 'age': 351},
#  {'_id': ObjectId('629986d9531fa74537c692e7'), 'name': 'Dascha', 'age': 352},
#  {'_id': ObjectId('629986d9531fa74537c692e8'), 'name': 'Dascha', 'age': 353},
#  {'_id': ObjectId('629986d9531fa74537c692e9'), 'name': 'Dascha', 'age': 354},
#  {'_id': ObjectId('629986d9531fa74537c692ed'), 'name': 'Dascha', 'age': 358},
#  {'_id': ObjectId('629986d9531fa74537c692f1'), 'name': 'Dascha', 'age': 362},
#  {'_id': ObjectId('629986d9531fa74537c692f2'), 'name': 'Dascha', 'age': 363},
#  {'_id': ObjectId('629986d9531fa74537c692f4'), 'name': 'Dascha', 'age': 365},
#  {'_id': ObjectId('629986d9531fa74537c692f7'), 'name': 'Dascha', 'age': 368},
#  {'_id': ObjectId('629986d9531fa74537c692fa'), 'name': 'Dascha', 'age': 371},
#  {'_id': ObjectId('629986d9531fa74537c692fb'), 'name': 'Dascha', 'age': 372},
#  {'_id': ObjectId('629986d9531fa74537c692ff'), 'name': 'Dascha', 'age': 376},
#  {'_id': ObjectId('629986d9531fa74537c69300'), 'name': 'Dascha', 'age': 377},
#  {'_id': ObjectId('629986d9531fa74537c69301'), 'name': 'Dascha', 'age': 378},
#  {'_id': ObjectId('629986d9531fa74537c69303'), 'name': 'Dascha', 'age': 380},
#  {'_id': ObjectId('629986d9531fa74537c69380'), 'name': 'Dascha', 'age': 505},
#  {'_id': ObjectId('629986d9531fa74537c69386'), 'name': 'Dascha', 'age': 511},
#  {'_id': ObjectId('629986d9531fa74537c69387'), 'name': 'Dascha', 'age': 512},
#  {'_id': ObjectId('629986d9531fa74537c69389'), 'name': 'Dascha', 'age': 514},
#  {'_id': ObjectId('629986d9531fa74537c6938a'), 'name': 'Dascha', 'age': 515},
#  {'_id': ObjectId('629986d9531fa74537c6938b'), 'name': 'Dascha', 'age': 516},
#  {'_id': ObjectId('629986d9531fa74537c6938d'), 'name': 'Dascha', 'age': 518},
#  {'_id': ObjectId('629986d9531fa74537c69390'), 'name': 'Dascha', 'age': 521},
#  {'_id': ObjectId('629986d9531fa74537c69393'), 'name': 'Dascha', 'age': 524},
#  {'_id': ObjectId('629986d9531fa74537c69394'), 'name': 'Dascha', 'age': 525},
#  {'_id': ObjectId('629986d9531fa74537c69395'), 'name': 'Dascha', 'age': 526},
#  {'_id': ObjectId('629986d9531fa74537c69398'), 'name': 'Dascha', 'age': 529},
#  {'_id': ObjectId('629986d9531fa74537c6939c'), 'name': 'Dascha', 'age': 533},
#  {'_id': ObjectId('629986d9531fa74537c6939e'), 'name': 'Dascha', 'age': 535},
#  {'_id': ObjectId('629986d9531fa74537c6939f'), 'name': 'Dascha', 'age': 536},
#  {'_id': ObjectId('629986d9531fa74537c693a0'), 'name': 'Dascha', 'age': 537},
#  {'_id': ObjectId('629986d9531fa74537c693a3'), 'name': 'Dascha', 'age': 540},
#  {'_id': ObjectId('629986d9531fa74537c693a4'), 'name': 'Dascha', 'age': 541},
#  {'_id': ObjectId('629986d9531fa74537c693a5'), 'name': 'Dascha', 'age': 542},
#  {'_id': ObjectId('629986d9531fa74537c693a6'), 'name': 'Dascha', 'age': 543},
#  {'_id': ObjectId('629986d9531fa74537c693aa'), 'name': 'Dascha', 'age': 547},
#  {'_id': ObjectId('629986d9531fa74537c693ab'), 'name': 'Dascha', 'age': 548},
#  {'_id': ObjectId('629986d9531fa74537c693ac'), 'name': 'Dascha', 'age': 549},
#  {'_id': ObjectId('629986d9531fa74537c693ae'), 'name': 'Dascha', 'age': 551},
#  {'_id': ObjectId('629986d9531fa74537c693b4'), 'name': 'Dascha', 'age': 557},
#  {'_id': ObjectId('629986d9531fa74537c693b5'), 'name': 'Dascha', 'age': 558},
#  {'_id': ObjectId('629986d9531fa74537c693b6'), 'name': 'Dascha', 'age': 559},
#  {'_id': ObjectId('629986d9531fa74537c693b7'), 'name': 'Dascha', 'age': 560},
#  {'_id': ObjectId('629986d9531fa74537c693b8'), 'name': 'Dascha', 'age': 561},
#  {'_id': ObjectId('629986d9531fa74537c693bb'), 'name': 'Dascha', 'age': 564},
#  {'_id': ObjectId('629986d9531fa74537c693bc'), 'name': 'Dascha', 'age': 565},
#  {'_id': ObjectId('629986d9531fa74537c693bf'), 'name': 'Dascha', 'age': 568},
#  {'_id': ObjectId('629986d9531fa74537c693c0'), 'name': 'Dascha', 'age': 569},
#  {'_id': ObjectId('629986d9531fa74537c693c1'), 'name': 'Dascha', 'age': 570},
#  {'_id': ObjectId('629986d9531fa74537c693c3'), 'name': 'Dascha', 'age': 572},
#  {'_id': ObjectId('629986d9531fa74537c693c4'), 'name': 'Dascha', 'age': 573},
#  {'_id': ObjectId('629986d9531fa74537c693c7'), 'name': 'Dascha', 'age': 576},
#  {'_id': ObjectId('629986d9531fa74537c693c8'), 'name': 'Dascha', 'age': 577},
#  {'_id': ObjectId('629986d9531fa74537c693c9'), 'name': 'Dascha', 'age': 578},
#  {'_id': ObjectId('629986d9531fa74537c693cb'), 'name': 'Dascha', 'age': 580},
#  {'_id': ObjectId('629986d9531fa74537c693cc'), 'name': 'Dascha', 'age': 581},
#  {'_id': ObjectId('629986d9531fa74537c693ce'), 'name': 'Dascha', 'age': 583},
#  {'_id': ObjectId('629986d9531fa74537c693cf'), 'name': 'Dascha', 'age': 584},
#  {'_id': ObjectId('629986d9531fa74537c693d4'), 'name': 'Dascha', 'age': 589},
#  {'_id': ObjectId('629986d9531fa74537c693db'), 'name': 'Dascha', 'age': 596},
#  {'_id': ObjectId('629986d9531fa74537c693dd'), 'name': 'Dascha', 'age': 598},
#  {'_id': ObjectId('629986d8531fa74537c6927c'), 'name': 'Dascha', 'age': 245},
#  {'_id': ObjectId('629986d8531fa74537c69283'), 'name': 'Dascha', 'age': 252},
#  {'_id': ObjectId('629986d8531fa74537c69284'), 'name': 'Dascha', 'age': 253},
#  {'_id': ObjectId('629986d8531fa74537c69285'), 'name': 'Dascha', 'age': 254},
#  {'_id': ObjectId('629986d8531fa74537c69287'), 'name': 'Dascha', 'age': 256},
#  {'_id': ObjectId('629986d8531fa74537c69288'), 'name': 'Dascha', 'age': 257},
#  {'_id': ObjectId('629986d8531fa74537c6928c'), 'name': 'Dascha', 'age': 261},
#  {'_id': ObjectId('629986d8531fa74537c69290'), 'name': 'Dascha', 'age': 265},
#  {'_id': ObjectId('629986d8531fa74537c69291'), 'name': 'Dascha', 'age': 266},
#  {'_id': ObjectId('629986d8531fa74537c69293'), 'name': 'Dascha', 'age': 268},
#  {'_id': ObjectId('629986d8531fa74537c69294'), 'name': 'Dascha', 'age': 269},
#  {'_id': ObjectId('629986d8531fa74537c69295'), 'name': 'Dascha', 'age': 270},
#  {'_id': ObjectId('629986d8531fa74537c69296'), 'name': 'Dascha', 'age': 271},
#  {'_id': ObjectId('629986d8531fa74537c69299'), 'name': 'Dascha', 'age': 274},
#  {'_id': ObjectId('629986d8531fa74537c6929a'), 'name': 'Dascha', 'age': 275},
#  {'_id': ObjectId('629986d8531fa74537c6929b'), 'name': 'Dascha', 'age': 276},
#  {'_id': ObjectId('629986d8531fa74537c6929c'), 'name': 'Dascha', 'age': 277},
#  {'_id': ObjectId('629986d8531fa74537c6929f'), 'name': 'Dascha', 'age': 280},
#  {'_id': ObjectId('629986d8531fa74537c692a0'), 'name': 'Dascha', 'age': 281},
#  {'_id': ObjectId('629986d8531fa74537c692a1'), 'name': 'Dascha', 'age': 282},
#  {'_id': ObjectId('629986d8531fa74537c692a3'), 'name': 'Dascha', 'age': 284},
#  {'_id': ObjectId('629986d8531fa74537c692a4'), 'name': 'Dascha', 'age': 285},
#  {'_id': ObjectId('629986d8531fa74537c692a5'), 'name': 'Dascha', 'age': 286},
#  {'_id': ObjectId('629986d8531fa74537c692a6'), 'name': 'Dascha', 'age': 287},
#  {'_id': ObjectId('629986d8531fa74537c692a7'), 'name': 'Dascha', 'age': 288},
#  {'_id': ObjectId('629986d8531fa74537c692ab'), 'name': 'Dascha', 'age': 292},
#  {'_id': ObjectId('629986d8531fa74537c692ad'), 'name': 'Dascha', 'age': 294},
#  {'_id': ObjectId('629986d8531fa74537c692ae'), 'name': 'Dascha', 'age': 295},
#  {'_id': ObjectId('629986d8531fa74537c692af'), 'name': 'Dascha', 'age': 296},
#  {'_id': ObjectId('629986d8531fa74537c692b1'), 'name': 'Dascha', 'age': 298},
#  {'_id': ObjectId('629986d8531fa74537c692b4'), 'name': 'Dascha', 'age': 301},
#  {'_id': ObjectId('629986d8531fa74537c692b5'), 'name': 'Dascha', 'age': 302},
#  {'_id': ObjectId('629986d8531fa74537c692b7'), 'name': 'Dascha', 'age': 304},
#  {'_id': ObjectId('629986d8531fa74537c692b8'), 'name': 'Dascha', 'age': 305},
#  {'_id': ObjectId('629986d8531fa74537c692bc'), 'name': 'Dascha', 'age': 309},
#  {'_id': ObjectId('629986d8531fa74537c692bd'), 'name': 'Dascha', 'age': 310},
#  {'_id': ObjectId('629986d9531fa74537c692be'), 'name': 'Dascha', 'age': 311},
#  {'_id': ObjectId('629986d9531fa74537c692bf'), 'name': 'Dascha', 'age': 312},
#  {'_id': ObjectId('629986d9531fa74537c692c0'), 'name': 'Dascha', 'age': 313},
#  {'_id': ObjectId('629986d9531fa74537c692c5'), 'name': 'Dascha', 'age': 318},
#  {'_id': ObjectId('629986d9531fa74537c692c6'), 'name': 'Dascha', 'age': 319},
#  {'_id': ObjectId('629986d9531fa74537c692c7'), 'name': 'Dascha', 'age': 320},
#  {'_id': ObjectId('629986d9531fa74537c692c9'), 'name': 'Dascha', 'age': 322},
#  {'_id': ObjectId('629986d9531fa74537c692ca'), 'name': 'Dascha', 'age': 323},
#  {'_id': ObjectId('629986d9531fa74537c692cc'), 'name': 'Dascha', 'age': 325},
#  {'_id': ObjectId('629986d9531fa74537c692cd'), 'name': 'Dascha', 'age': 326},
#  {'_id': ObjectId('629986d9531fa74537c692d0'), 'name': 'Dascha', 'age': 329},
#  {'_id': ObjectId('629986d9531fa74537c692d1'), 'name': 'Dascha', 'age': 330},
#  {'_id': ObjectId('629986d9531fa74537c692d2'), 'name': 'Dascha', 'age': 331},
#  {'_id': ObjectId('629986d9531fa74537c692d4'), 'name': 'Dascha', 'age': 333},
#  {'_id': ObjectId('629986d9531fa74537c692d6'), 'name': 'Dascha', 'age': 335},
#  {'_id': ObjectId('629986d9531fa74537c692d8'), 'name': 'Dascha', 'age': 337},
#  {'_id': ObjectId('629986d9531fa74537c692d9'), 'name': 'Dascha', 'age': 338},
#  {'_id': ObjectId('629986d9531fa74537c692db'), 'name': 'Dascha', 'age': 340},
#  {'_id': ObjectId('629986d9531fa74537c692dc'), 'name': 'Dascha', 'age': 341},
#  {'_id': ObjectId('629986d9531fa74537c692df'), 'name': 'Dascha', 'age': 344},
#  {'_id': ObjectId('629986d9531fa74537c692e1'), 'name': 'Dascha', 'age': 346},
#  {'_id': ObjectId('629986d9531fa74537c692e2'), 'name': 'Dascha', 'age': 347},
#  {'_id': ObjectId('629986d9531fa74537c692e3'), 'name': 'Dascha', 'age': 348},
#  {'_id': ObjectId('629986d9531fa74537c692e4'), 'name': 'Dascha', 'age': 349},
#  {'_id': ObjectId('629986d9531fa74537c692ea'), 'name': 'Dascha', 'age': 355},
#  {'_id': ObjectId('629986d9531fa74537c692eb'), 'name': 'Dascha', 'age': 356},
#  {'_id': ObjectId('629986d9531fa74537c692ec'), 'name': 'Dascha', 'age': 357},
#  {'_id': ObjectId('629986d9531fa74537c692ee'), 'name': 'Dascha', 'age': 359},
#  {'_id': ObjectId('629986d9531fa74537c692ef'), 'name': 'Dascha', 'age': 360},
#  {'_id': ObjectId('629986d9531fa74537c692f0'), 'name': 'Dascha', 'age': 361},
#  {'_id': ObjectId('629986d9531fa74537c692f3'), 'name': 'Dascha', 'age': 364},
#  {'_id': ObjectId('629986d9531fa74537c692f5'), 'name': 'Dascha', 'age': 366},
#  {'_id': ObjectId('629986d9531fa74537c692f6'), 'name': 'Dascha', 'age': 367},
#  {'_id': ObjectId('629986d9531fa74537c692f8'), 'name': 'Dascha', 'age': 369},
#  {'_id': ObjectId('629986d9531fa74537c692f9'), 'name': 'Dascha', 'age': 370},
#  {'_id': ObjectId('629986d9531fa74537c692fc'), 'name': 'Dascha', 'age': 373},
#  {'_id': ObjectId('629986d9531fa74537c692fd'), 'name': 'Dascha', 'age': 374},
#  {'_id': ObjectId('629986d9531fa74537c692fe'), 'name': 'Dascha', 'age': 375},
#  {'_id': ObjectId('629986d9531fa74537c69302'), 'name': 'Dascha', 'age': 379},
#  {'_id': ObjectId('629986d9531fa74537c69305'), 'name': 'Dascha', 'age': 382},
#  {'_id': ObjectId('629986d9531fa74537c69308'), 'name': 'Dascha', 'age': 385},
#  {'_id': ObjectId('629986d9531fa74537c69309'), 'name': 'Dascha', 'age': 386},
#  {'_id': ObjectId('629986d9531fa74537c6930a'), 'name': 'Dascha', 'age': 387},
#  {'_id': ObjectId('629986d9531fa74537c6930b'), 'name': 'Dascha', 'age': 388},
#  {'_id': ObjectId('629986d9531fa74537c6930f'), 'name': 'Dascha', 'age': 392},
#  {'_id': ObjectId('629986d9531fa74537c69310'), 'name': 'Dascha', 'age': 393},
#  {'_id': ObjectId('629986d9531fa74537c69313'), 'name': 'Dascha', 'age': 396},
#  {'_id': ObjectId('629986d9531fa74537c69314'), 'name': 'Dascha', 'age': 397},
#  {'_id': ObjectId('629986d9531fa74537c6931a'), 'name': 'Dascha', 'age': 403},
#  {'_id': ObjectId('629986d9531fa74537c6931c'), 'name': 'Dascha', 'age': 405},
#  {'_id': ObjectId('629986d9531fa74537c6931d'), 'name': 'Dascha', 'age': 406},
#  {'_id': ObjectId('629986d9531fa74537c69322'), 'name': 'Dascha', 'age': 411},
#  {'_id': ObjectId('629986d9531fa74537c69323'), 'name': 'Dascha', 'age': 412},
#  {'_id': ObjectId('629986d9531fa74537c69325'), 'name': 'Dascha', 'age': 414},
#  {'_id': ObjectId('629986d9531fa74537c69326'), 'name': 'Dascha', 'age': 415},
#  {'_id': ObjectId('629986d9531fa74537c69327'), 'name': 'Dascha', 'age': 416},
#  {'_id': ObjectId('629986d9531fa74537c69328'), 'name': 'Dascha', 'age': 417},
#  {'_id': ObjectId('629986d9531fa74537c69329'), 'name': 'Dascha', 'age': 418},
#  {'_id': ObjectId('629986d9531fa74537c6932a'), 'name': 'Dascha', 'age': 419},
#  {'_id': ObjectId('629986d9531fa74537c6932c'), 'name': 'Dascha', 'age': 421},
#  {'_id': ObjectId('629986d9531fa74537c6932d'), 'name': 'Dascha', 'age': 422},
#  {'_id': ObjectId('629986d9531fa74537c69330'), 'name': 'Dascha', 'age': 425},
#  {'_id': ObjectId('629986d9531fa74537c69331'), 'name': 'Dascha', 'age': 426},
#  {'_id': ObjectId('629986d9531fa74537c69334'), 'name': 'Dascha', 'age': 429},
#  {'_id': ObjectId('629986d9531fa74537c69335'), 'name': 'Dascha', 'age': 430},
#  {'_id': ObjectId('629986d9531fa74537c69337'), 'name': 'Dascha', 'age': 432},
#  {'_id': ObjectId('629986d9531fa74537c69338'), 'name': 'Dascha', 'age': 433},
#  {'_id': ObjectId('629986d9531fa74537c6933c'), 'name': 'Dascha', 'age': 437},
#  {'_id': ObjectId('629986d9531fa74537c6933d'), 'name': 'Dascha', 'age': 438},
#  {'_id': ObjectId('629986d9531fa74537c6933f'), 'name': 'Dascha', 'age': 440},
#  {'_id': ObjectId('629986d9531fa74537c69346'), 'name': 'Dascha', 'age': 447},
#  {'_id': ObjectId('629986d9531fa74537c69347'), 'name': 'Dascha', 'age': 448},
#  {'_id': ObjectId('629986d9531fa74537c69349'), 'name': 'Dascha', 'age': 450},
#  {'_id': ObjectId('629986d9531fa74537c6934a'), 'name': 'Dascha', 'age': 451},
#  {'_id': ObjectId('629986d9531fa74537c69350'), 'name': 'Dascha', 'age': 457},
#  {'_id': ObjectId('629986d9531fa74537c69351'), 'name': 'Dascha', 'age': 458},
#  {'_id': ObjectId('629986d9531fa74537c69354'), 'name': 'Dascha', 'age': 461},
#  {'_id': ObjectId('629986d9531fa74537c69355'), 'name': 'Dascha', 'age': 462},
#  {'_id': ObjectId('629986d9531fa74537c69356'), 'name': 'Dascha', 'age': 463},
#  {'_id': ObjectId('629986d9531fa74537c69357'), 'name': 'Dascha', 'age': 464},
#  {'_id': ObjectId('629986d9531fa74537c69358'), 'name': 'Dascha', 'age': 465},
#  {'_id': ObjectId('629986d9531fa74537c6935d'), 'name': 'Dascha', 'age': 470},
#  {'_id': ObjectId('629986d9531fa74537c69362'), 'name': 'Dascha', 'age': 475},
#  {'_id': ObjectId('629986d9531fa74537c69364'), 'name': 'Dascha', 'age': 477},
#  {'_id': ObjectId('629986d9531fa74537c69366'), 'name': 'Dascha', 'age': 479},
#  {'_id': ObjectId('629986d9531fa74537c69367'), 'name': 'Dascha', 'age': 480},
#  {'_id': ObjectId('629986d9531fa74537c6936d'), 'name': 'Dascha', 'age': 486},
#  {'_id': ObjectId('629986d9531fa74537c69371'), 'name': 'Dascha', 'age': 490},
#  {'_id': ObjectId('629986d9531fa74537c69376'), 'name': 'Dascha', 'age': 495},
#  {'_id': ObjectId('629986d9531fa74537c69378'), 'name': 'Dascha', 'age': 497},
#  {'_id': ObjectId('629986d9531fa74537c6937a'), 'name': 'Dascha', 'age': 499},
#  {'_id': ObjectId('629986d9531fa74537c6937b'), 'name': 'Dascha', 'age': 500},
#  {'_id': ObjectId('629986d9531fa74537c6937c'), 'name': 'Dascha', 'age': 501},
#  {'_id': ObjectId('629986d9531fa74537c6937e'), 'name': 'Dascha', 'age': 503},
#  {'_id': ObjectId('629986d9531fa74537c6937f'), 'name': 'Dascha', 'age': 504},
#  {'_id': ObjectId('629986d9531fa74537c69381'), 'name': 'Dascha', 'age': 506},
#  {'_id': ObjectId('629986d9531fa74537c69382'), 'name': 'Dascha', 'age': 507},
#  {'_id': ObjectId('629986d9531fa74537c69383'), 'name': 'Dascha', 'age': 508},
#  {'_id': ObjectId('629986d9531fa74537c69384'), 'name': 'Dascha', 'age': 509},
#  {'_id': ObjectId('629986d9531fa74537c69385'), 'name': 'Dascha', 'age': 510},
#  {'_id': ObjectId('629986d9531fa74537c69388'), 'name': 'Dascha', 'age': 513},
#  {'_id': ObjectId('629986d9531fa74537c6938c'), 'name': 'Dascha', 'age': 517},
#  {'_id': ObjectId('629986d9531fa74537c6938e'), 'name': 'Dascha', 'age': 519},
#  {'_id': ObjectId('629986d9531fa74537c6938f'), 'name': 'Dascha', 'age': 520},
#  {'_id': ObjectId('629986d9531fa74537c69391'), 'name': 'Dascha', 'age': 522},
#  {'_id': ObjectId('629986d9531fa74537c69392'), 'name': 'Dascha', 'age': 523},
#  {'_id': ObjectId('629986d9531fa74537c69396'), 'name': 'Dascha', 'age': 527},
#  {'_id': ObjectId('629986d9531fa74537c69397'), 'name': 'Dascha', 'age': 528},
#  {'_id': ObjectId('629986d9531fa74537c69399'), 'name': 'Dascha', 'age': 530},
#  {'_id': ObjectId('629986d9531fa74537c6939a'), 'name': 'Dascha', 'age': 531},
#  {'_id': ObjectId('629986d9531fa74537c6939b'), 'name': 'Dascha', 'age': 532},
#  {'_id': ObjectId('629986d9531fa74537c6939d'), 'name': 'Dascha', 'age': 534},
#  {'_id': ObjectId('629986d9531fa74537c693a1'), 'name': 'Dascha', 'age': 538},
#  {'_id': ObjectId('629986d9531fa74537c693a2'), 'name': 'Dascha', 'age': 539},
#  {'_id': ObjectId('629986d9531fa74537c693a7'), 'name': 'Dascha', 'age': 544},
#  {'_id': ObjectId('629986d9531fa74537c693a8'), 'name': 'Dascha', 'age': 545},
#  {'_id': ObjectId('629986d9531fa74537c693a9'), 'name': 'Dascha', 'age': 546},
#  {'_id': ObjectId('629986d9531fa74537c693ad'), 'name': 'Dascha', 'age': 550},
#  {'_id': ObjectId('629986d9531fa74537c693af'), 'name': 'Dascha', 'age': 552},
#  {'_id': ObjectId('629986d9531fa74537c693b0'), 'name': 'Dascha', 'age': 553},
#  {'_id': ObjectId('629986d9531fa74537c693b1'), 'name': 'Dascha', 'age': 554},
#  {'_id': ObjectId('629986d9531fa74537c693b2'), 'name': 'Dascha', 'age': 555},
#  {'_id': ObjectId('629986d9531fa74537c693b3'), 'name': 'Dascha', 'age': 556},
#  {'_id': ObjectId('629986d9531fa74537c693b9'), 'name': 'Dascha', 'age': 562},
#  {'_id': ObjectId('629986d9531fa74537c693ba'), 'name': 'Dascha', 'age': 563},
#  {'_id': ObjectId('629986d9531fa74537c693bd'), 'name': 'Dascha', 'age': 566},
#  {'_id': ObjectId('629986d9531fa74537c693be'), 'name': 'Dascha', 'age': 567},
#  {'_id': ObjectId('629986d9531fa74537c693c2'), 'name': 'Dascha', 'age': 571},
#  {'_id': ObjectId('629986d9531fa74537c693c5'), 'name': 'Dascha', 'age': 574},
#  {'_id': ObjectId('629986d9531fa74537c693c6'), 'name': 'Dascha', 'age': 575},
#  {'_id': ObjectId('629986d9531fa74537c693ca'), 'name': 'Dascha', 'age': 579},
#  {'_id': ObjectId('629986d9531fa74537c693cd'), 'name': 'Dascha', 'age': 582},
#  {'_id': ObjectId('629986d9531fa74537c693d0'), 'name': 'Dascha', 'age': 585},
#  {'_id': ObjectId('629986d9531fa74537c693d1'), 'name': 'Dascha', 'age': 586},
#  {'_id': ObjectId('629986d9531fa74537c693d2'), 'name': 'Dascha', 'age': 587},
#  {'_id': ObjectId('629986d9531fa74537c693d3'), 'name': 'Dascha', 'age': 588},
#  {'_id': ObjectId('629986d9531fa74537c693d5'), 'name': 'Dascha', 'age': 590},
#  {'_id': ObjectId('629986d9531fa74537c693d6'), 'name': 'Dascha', 'age': 591},
#  {'_id': ObjectId('629986d9531fa74537c693d7'), 'name': 'Dascha', 'age': 592},
#  {'_id': ObjectId('629986d9531fa74537c693d8'), 'name': 'Dascha', 'age': 593},
#  {'_id': ObjectId('629986d9531fa74537c693d9'), 'name': 'Dascha', 'age': 594},
#  {'_id': ObjectId('629986d9531fa74537c693da'), 'name': 'Dascha', 'age': 595},
#  {'_id': ObjectId('629986d9531fa74537c693dc'), 'name': 'Dascha', 'age': 597},
#  {'_id': ObjectId('629986d9531fa74537c693de'), 'name': 'Dascha', 'age': 599}]

# %% [markdown]
# Теперь можно посмотреть, что произошло с кластером. Для этого можно переключиться на базу данных config и запросить количество порций :
#
# > use config
#
# > db.chunks.count()
#
# Рассмотрим количество документов, которые были добавлены:
#
# > db.mycollect.count()
#
# Рассмотрим объем памяти, занятый данными:
#
# > db.mycollect.stats().size
#
# Для получения более детальной информации вызовем метод sh.status(), который напечатает все порции с указанием их диапазонов.
#
# > sh.status()
#
# Можно попробовать добавлять документы прямо в консоле:
#
# > use rebus
#
# > for (var i=0; i<2100000; i++) { db.mycollect.insert({name: "Max", amount:Math.random()*100})}
#
# Чтобы посмотреть, сколько порций выделено в каждом сегменте, можно использовать команды:
#
# > db.chunks.count({"shard": "shard-a"})
#
# > db.chunks.count({"shard": "shard-b"})
