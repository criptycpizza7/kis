# %%
install.packages("CCA")
library(CCA)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘Rcpp’, ‘misc3d’, ‘mvtnorm’, ‘locfit’, ‘ash’, ‘FNN’, ‘kernlab’, ‘mclust’, ‘multicool’, ‘plot3D’, ‘pracma’, ‘pcaPP’, ‘hdrcde’, ‘ks’, ‘bitops’, ‘rainbow’, ‘RCurl’, ‘dotCall64’, ‘gridExtra’, ‘fds’, ‘deSolve’, ‘spam’, ‘viridis’, ‘maps’, ‘fda’, ‘fields’
#
#
# Loading required package: fda
#
# Loading required package: splines
#
# Loading required package: fds
#
# Loading required package: rainbow
#
# Loading required package: MASS
#
# Loading required package: pcaPP
#
# Loading required package: RCurl
#
# Loading required package: deSolve
#
#
# Attaching package: ‘fda’
#
#
# The following object is masked from ‘package:graphics’:
#
#     matplot
#
#
# Loading required package: fields
#
# Loading required package: spam
#
# Spam version 2.9-1 (2022-08-07) is loaded.
# Type 'help( Spam)' or 'demo( spam)' for a short introduction
# and overview of this package.
# ...

# %%
y<-rnorm(100,0,6)

# %%
plot(x,y)
# Out:
# plot without title

# %%
!ls
# Out:
# Error in !ls: invalid argument type
# Traceback:

# %%
system2("ls", args="-a", stdout=TRUE)
# Out:
# [1] "."           ".."          ".config"     "sample_data" "test"

# %%
system2("cd ..")
# Out:
# Warning message in system2("cd .."):
# “error in running command”

# %%
system2("mkdir", args="test" )

# %%
help(system2)
